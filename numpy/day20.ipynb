# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Price" : [100,200,300]
})
df
# Out:
#    Price
# 0    100
# 1    200
# 2    300

# %%
print(type(df["Price"].values))
# Out:
# <class 'numpy.ndarray'>

# %%
# install numpy
pip install numpy

# %%
# import numpy 
import numpy as np

# %%
# list 
salary = [1000,2000,3000]

# convert list to array 
salary_array = np.array(salary)
type(salary_array)
# Out:
# numpy.ndarray

# %%
new_salary_array = salary_array + 1   # vectorization
new_salary_array
# Out:
# array([1001, 2001, 3001])

# %%
s_array = np.array([100,200,300])  # one dimensional array
s_array
# Out:
# array([100, 200, 300])

# %%
# two dimensional array
data
# Out:
# array([[  10, 1000],
#        [  20, 2000],
#        [  30, 3000]])

# %%
# check number of dimensional
print(s_array.ndim)
print(data.ndim)
# Out:
# 1
# 2

# %%
# shape of array (provides no of rows and columns (rows, columns) also called as (rows, features))
print(s_array.shape)
print(data.shape)
# Out:
# (3,)
# (3, 2)

# %%
# total numbers of values ||| product of rows and columns
print(s_array.size)
print(data.size)
# Out:
# 3
# 6

# %%
# data type 
# in numpy array , data must be homogeneous type 
print(data.dtype)
# Out:
# int64

# %%
# print complete row || print one dimensional value
print(data[0])

# print columns value as per index
print(data[0,1])
# Out:
# [  10 1000]
# 1000

# %%
# slicing data 
datas = np.array([
    [10,1001],
    [20,2001],
    [30,3001],
    [10,1002],
    [20,2002],
    [30,3002]
])

datas[:3]    # from index 0 to 2
datas[2:5]    # from index 2 to 4
# Out:
# array([[  30, 3001],
#        [  10, 1002],
#        [  20, 2002]])

# %%
# extract data from second columns
print(datas[:,1])
# Out:
# [1001 2001 3001 1002 2002 3002]
