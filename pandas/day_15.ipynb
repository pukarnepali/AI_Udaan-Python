# %%
import pandas as pd

# %%
bdd = pd.read_csv("../datasets/bad_daraz_dataset.csv")
bdd
# Out:
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics    NaN               15     4.6
# 2            3        Shoes      Fashion   3500               5%     4.2
# 3            4      T-Shirt      Fashion   1500               20     NaN
# 4            5        Watch  Accessories   5500               10     4.5
# 5            6   Headphones  Electronics   4200              NaN     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 7            8          Bag      Fashion    abc               12     3.9
# 8            9        Mouse  Electronics   1800                5     4.3
# 9            9          Cup  Electronics   1800                5     4.3
# 10          10     Keyboard  Electronics   2500                5     4.4
# 11          11       Bottle         Home    800                0     5.5
# ...

# %%
# grouping 
bdd.groupby("category")

# %%
# to have a look on output 

for category,data in bdd.groupby("category"):
    print(category)
    print("Rows", len(data))
    print(data)
# Out:
# Accessories
# Rows 1
#    product_id product_name     category price discount_percent  rating  \
# 4           5        Watch  Accessories  5500               10     4.5
#
#           stock seller       city  brand gender_target age  reviews
# 4  Out of Stock  TimeX  KATHMANDU  Casio          Male  28       80
# Electronics
# Rows 7
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics    NaN               15     4.6
# 5            6   Headphones  Electronics   4200              NaN     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 8            9        Mouse  Electronics   1800                5     4.3
# 9            9          Cup  Electronics   1800                5     4.3
# 10          10     Keyboard  Electronics   2500                5     4.4
#
# ...

# %%
# individual category
Electronics = bdd.groupby("category").get_group("Electronics")
Electronics
# Out:
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics    NaN               15     4.6
# 5            6   Headphones  Electronics   4200              NaN     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 8            9        Mouse  Electronics   1800                5     4.3
# 9            9          Cup  Electronics   1800                5     4.3
# 10          10     Keyboard  Electronics   2500                5     4.4
#
#    stock       seller         city     brand gender_target   age  reviews
# 0     25      TechHub    KaThmandu      Dell        Unisex    25      120
# 1     40  GadgetNepal      Pokhara   Samsung        Unisex    30      210
# 5     75     AudioPro      Pokhara       JBL        Unisex   24        65
# 6     25      TechHub    Kathmandu      Dell        Unisex    25      120
# ...

# %%
Fashion = bdd.groupby("category").get_group("Fashion")
Fashion
# Out:
#    product_id product_name category price discount_percent  rating stock  \
# 2           3        Shoes  Fashion  3500               5%     4.2    60
# 3           4      T-Shirt  Fashion  1500               20     NaN   150
# 7           8          Bag  Fashion   abc               12     3.9    45
#
#        seller        city      brand gender_target     age  reviews
# 2  FashionHub     Itahari       Nike          Male      22       55
# 3       Style  Biratnagar     Adidas        Female  Female       30
# 7    CarryAll      Dharan  Wildcraft        Female      19       18

# %%
for city,data in bdd.groupby("city"):
    print(city)
# Out:
#  KAthmandu
# Biratnagar
# Dharan
# Itahari
# Janakpur
# KATHMANDU
# KaThmandu
# Kathmandu
# Lalitpur
# Pokhara

# %%
kathmandu = bdd.groupby("city").get_group("Kathmandu")
kathmandu
# Out:
#    product_id product_name     category  price discount_percent  rating stock  \
# 6           7       Laptop  Electronics  75000               10     4.8    25
# 8           9        Mouse  Electronics   1800                5     4.3   NaN
# 9           9          Cup  Electronics   1800                5     4.3   NaN
#
#     seller       city     brand gender_target  age  reviews
# 6  TechHub  Kathmandu      Dell        Unisex   25      120
# 8  TechHub  Kathmandu  Logitech        Unisex  NaN       90
# 9  TechHub  Kathmandu  Logitech        Unisex  NaN       90

# %%
# count() (grouping and aggregation)
bdd.groupby("category")["product_name"].count()
# Out:
# category
# Accessories    1
# Electronics    7
# Fashion        3
# Furniture      2
# Home           1
# Name: product_name, dtype: int64

# %%
# max() (grouping and aggregation)
bdd.groupby("category")["price"].max()
# Out:
# category
# Accessories     5500
# Electronics     1800
# Fashion         1500
# Furniture      -2500
# Home             800
# Name: price, dtype: str

# %%
# min() (grouping and aggregation)
bdd.groupby("category")["price"].min()
# Out:
# category
# Accessories     5500
# Electronics     1800
# Fashion         1500
# Furniture      -2500
# Home             800
# Name: price, dtype: str

# %%
# max(),min() and count() (grouping and multiple aggregation)
bdd.groupby("category")["price"].agg(["max","min","count"])
# Out:
#                max    min  count
# category
# Accessories   5500   5500      1
# Electronics  75000   1800      6
# Fashion        abc   1500      3
# Furniture    -2500  -2500      2
# Home           800    800      1

# %%
# grouping plus muptiple aggregation
# bdd.groupby("category")["rating"].min()
bdd.groupby("category").agg({
    "price" : "min",
    "rating" : "max",
    "reviews" : "sum"
})
# Out:
#              price  rating  reviews
# category
# Accessories   5500     4.5       80
# Electronics   1800     4.8      805
# Fashion       1500     4.2      103
# Furniture    -2500     4.0       88
# Home           800     5.5       12
