# %% [markdown]
# # Function in python
# a block of code which can replace the duplication of code,
# even can make code more managable and simple.

# %% [markdown]
# #syntax of function
#
# def function_name():
#     block of code/statement

# %%
names = ["pukar", "akash", "manis"]

def greet():
    print("Hello", i)

for i in names:
    greet()
# Out:
# Hello pukar
# Hello akash
# Hello manis
